# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >Snowflake sits in the lower framework below where it allows connection, processing, and storage.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Comparison of Snowflake Tables
#
# ![image.png](attachment:image.png)
