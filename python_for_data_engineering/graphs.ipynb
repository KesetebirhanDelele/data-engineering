# %% [markdown]
# # 4 Type of Graphs
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %% [markdown]
# ## 1. Plotly: Interactive Visualizations Like Never Before

# %%
import plotly.express as px

data = {'Category': ['A', 'B', 'C'], 'Value': [10, 15, 7]}
df = pd.DataFrame(data)
fig = px.bar(df, x='Category', y='Value')
fig.show()

# %% [markdown]
# ## 2. Seaborn: Beauty and Simplicity Combined

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## 3. Matplotlib: The Classic Choice for Versatile Visualizations

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 4. Altair: Declarative Visualization in a Snap

# %%
pip install altair vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt
from vega_datasets import data

cars = data.cars()
alt.Chart(cars).mark_circle().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 5. Bokeh: Interactive Visualizations for the Web

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.sampledata.iris import flowers

p = figure(title='Iris Dataset', x_axis_label='Petal Length', y_axis_label='Petal Width')
p.add_tools(HoverTool(tooltips=[('Species', '@species'), ('Sepal Width', '@sepal_width')]))
p.circle(x='petal_length', y='petal_width', size=8, source=flowers)
show(p)

# %% [markdown]
# ![bokeh_plot.png](attachment:bokeh_plot.png)

# %% [markdown]
# ## 6. ggplot: Harnessing the Power of R’s ggplot2
#
# Note: ggplots in Python is not worth it. There is a need to do troubleshooting.
# > Reference: https://stackoverflow.com/questions/58143253/module-pandas-has-no-attribute-tslib

# %%
pip install ggplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## ggplot in Python not worth it

# %%
import pandas as pd
from ggplot import *

df = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [10, 8, 6, 4, 2]})
ggplot(aes(x='x', y='y'), data=df) + geom_point()
# Out:
# <ggplot: (182358774839)>

# %% [markdown]
# ## 7. NetworkX: Visualizing Complex Networks

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.karate_club_graph()
nx.draw_networkx(G, with_labels=True)
plt.show()

# %% [markdown]
# ## 8. Wordcloud: Unleash the Power of Text Visualization

# %%
pip install wordcloud
# Out:
# ...
#      -------------------------------------- 152.1/152.1 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "CNN—A shooter wearing a bulletproof vest and a ski mask fired randomly at vehicles and pedestrians Monday night in southwest Philadelphia, killing five people and wounding two others, authorities said. In a Tuesday afternoon news conference, Philadelphia Police Commissioner Danielle M. Outlaw told reporters the “armed and armored” assailant was firing seemingly at random people, including a mother driving her twins home, in the Kingsessing neighborhood.'What happened last night was unimaginably disgusting and horrifying,' Outlaw said."
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 9. Pygal: Interactive SVG Charts

# %%
pip install pygal
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygal

bar_chart = pygal.Bar()
bar_chart.add('Series', [1, 3, 2, 5, 4])
bar_chart.render()

# Import svg extention into vscode, then Save output link in a .svg file format and right click on 
# 'Preview svg' to see the graph
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ae100c63-cab1-4a28-ae30-1cb176f90d96" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2023-07-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ae100c63-cab1-4a28-ae30-1cb176f90d96{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ae100c63-cab1-4a28-ae30-1cb176f90d96 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ae100c63-cab1-4a28-ae30-1cb176f90d96 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ae100c63-cab1-4a28-ae30-1cb176f90d96 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ae100c63-cab1-4a28-ae30-1cb176f90
# ...

# %% [markdown]
# ## 10. Folium: Maps Made Easy

# %%
pip install folium
# Out:
# ...
#      -------------------------------------- 102.3/102.3 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

m = folium.Map(location=[9.005401, 38.763611], zoom_start=12)
folium.Marker(location=[9.005401, 38.763611], popup='Addis Ababa').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
