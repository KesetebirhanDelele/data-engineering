# %% [markdown]
# # Docker terminology

# %% [markdown]
# > A code is written to build a docker image.
#
# > Different versions are stored in a registry by push commands
#
# > Images are pull from registry and run. Each instance will have a name and ID along with different environment variables, volumes, ports, and networks.
#
# > Tags are used to keep track of versions. Latest_tag is used to store the latest version

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
