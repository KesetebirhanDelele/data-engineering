# %%
import pandas as pd

# %% [markdown]
# 1. Creating DataFrames

# %%
# Option 1: Using Dictionary as data source
df_dictionary = pd.DataFrame(
{"a" : [4, 5, 6], 
"b" : [7, 8, 9], 
"c" : [10, 11, 12]}, 
index = [1, 2, 3])
df_dictionary
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
# Option 1b: without index: row number will by default start from 0
df_default = pd.DataFrame(
{"a" : [4, 5, 6], 
"b" : [7, 8, 9], 
"c" : [10, 11, 12]})
df_default
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
# Option 2: Using list of lists
df_list = pd.DataFrame(
[[4, 5, 6], 
[7, 8, 9], 
[10, 11, 12]], 
index = [1, 2, 3],
columns = ['a', 'b', 'c'])
df_list
# Out:
#     a   b   c
# 1   4   5   6
# 2   7   8   9
# 3  10  11  12

# %%
# Option 3: multi-index
df_multiindex = pd.DataFrame(
{"a" : [4 ,5, 6], 
"b" : [7, 8, 9], 
"c" : [10, 11, 12]}, 
index = pd.MultiIndex.from_tuples(
[('d', 1), ('d', 2),
('e', 2)], names=['n', 'v']))
df_multiindex
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %% [markdown]
# 2. Reading a CSV file

# %%
df=pd.read_csv('../data/Demo_sales_data.csv')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08/11/2021  11/11/2021    Second Class    CG-12520
# 1       2  CA-2016-152156  08/11/2021  11/11/2021    Second Class    CG-12520
# 2       3  CA-2016-138688  12/06/2021  16/06/2021    Second Class    DV-13045
# 3      14  CA-2016-161389  05/12/2021  10/12/2021  Standard Class    IM-15070
# 4      22  CA-2016-137330  09/12/2021  13/12/2021  Standard Class    KB-16585
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
# 3     Irene Maddox   Consumer  United States      Seattle  ...       98103
# 4        Ken Black  Corporate  United States      Fremont  ...       68025
#
#     Region       Product ID         Category Sub-Category  \
# 0    South  FUR-BO-10001798        Furniture    Bookcases
# 1    South  FUR-CH-10000454        Furniture       Chairs
# 2     West  OFF-LA-10000240  Office Supplies       Labels
# 3     West  OFF-BI-10003656  Office Supplies      Binders
# 4  Central  OFF-AR-10000246  Office Supplies          Art
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
# 3        Fellowes PB200 Plastic Comb Binding Machine  407.98         3
# 4                                         Newell 318   19.46         7
#
#    Discount  Profit
# 0       0.0   41.91
# 1       0.0  219.58
# 2       0.0    6.87
# 3       0.2  132.59
# 4       0.0    5.06
#
# [5 rows x 21 columns]

# %% [markdown]
# 3. Selecting Subset of a Dataset

# %%
# Selecting a column as data series
df_segment=df['Segment']
df_segment.head()
# Out:
# 0     Consumer
# 1     Consumer
# 2    Corporate
# 3     Consumer
# 4    Corporate
# Name: Segment, dtype: object

# %%
# Selecting a column: alternative
df.Segment
# Out:
# 0          Consumer
# 1          Consumer
# 2         Corporate
# 3          Consumer
# 4         Corporate
#            ...
# 2582    Home Office
# 2583    Home Office
# 2584       Consumer
# 2585       Consumer
# 2586       Consumer
# Name: Segment, Length: 2587, dtype: object

# %%
# Selecting columns as dataframe along with column names
df_subset=df[['Row ID','Segment']]
df_subset.head()
# Out:
#    Row ID    Segment
# 0       1   Consumer
# 1       2   Consumer
# 2       3  Corporate
# 3      14   Consumer
# 4      22  Corporate

# %%
# Selecting rows using query, loc or dataframe
x=df_subset.query("Segment=='Consumer'").head()
y=df_subset[df_subset["Segment"]=='Corporate'].head()
z=df_subset.loc[df_subset['Segment']=='Home Office'].head()
print("Filtering using query")
print(x)
print("Filtering using dataframe")
print(y)
print("Filtering using loc")
print(z)
# Out:
# Filtering using query
#    Row ID   Segment
# 0       1  Consumer
# 1       2  Consumer
# 3      14  Consumer
# 6      26  Consumer
# 7      27  Consumer
# Filtering using dataframe
#    Row ID    Segment
# 2       3  Corporate
# 4      22  Corporate
# 5      23  Corporate
# 8      36  Corporate
# 9      37  Corporate
# Filtering using loc
#     Row ID      Segment
# 28      89  Home Office
# 33     100  Home Office
# 34     101  Home Office
# 35     102  Home Office
# 44     129  Home Office

# %%
df['Segment']
# Out:
# 0          Consumer
# 1          Consumer
# 2         Corporate
# 3          Consumer
# 4         Corporate
#            ...
# 2582    Home Office
# 2583    Home Office
# 2584       Consumer
# 2585       Consumer
# 2586       Consumer
# Name: Segment, Length: 2587, dtype: object

# %%
df.query("Segment=='Corporate'")
df_subset.query("Segment=='Consumer'" or "Segment=='Corporate'")
# Out:
#       Row ID   Segment
# 0          1  Consumer
# 1          2  Consumer
# 3         14  Consumer
# 6         26  Consumer
# 7         27  Consumer
# ...      ...       ...
# 2568    9936  Consumer
# 2576    9973  Consumer
# 2584    9983  Consumer
# 2585    9984  Consumer
# 2586    9987  Consumer
#
# [1328 rows x 2 columns]

# %%
df[df["Postal Code"].isin(range(10000,50000))].head()
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156  08/11/2021  11/11/2021    Second Class
# 1        2  CA-2016-152156  08/11/2021  11/11/2021    Second Class
# 13      48  CA-2016-169194  20/06/2021  25/06/2021  Standard Class
# 14      49  CA-2016-169194  20/06/2021  25/06/2021  Standard Class
# 15      54  CA-2016-105816  11/12/2021  17/12/2021  Standard Class
#
#    Customer ID   Customer Name    Segment        Country           City  ...  \
# 0     CG-12520     Claire Gute   Consumer  United States      Henderson  ...
# 1     CG-12520     Claire Gute   Consumer  United States      Henderson  ...
# 13    LH-16900  Lena Hernandez   Consumer  United States          Dover  ...
# 14    LH-16900  Lena Hernandez   Consumer  United States          Dover  ...
# 15    JM-15265  Janet Molinari  Corporate  United States  New York City  ...
#
#    Postal Code  Region       Product ID         Category Sub-Category  \
# 0        42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420   South  FUR-CH-10000454        Furniture       Chairs
# 13       19901    East  TEC-AC-10002167       Technology  Accessories
# 14       19901    East  TEC-PH-10003988       Technology       Phones
# 15       10024    East  OFF-FA-10000304  Office Supplies    Fasteners
#
#                                          Product Name   Sales  Quantity  \
# 0                   Bush Somerset Collection Bookcase  261.96         2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 13  Imation 8gb Micro Traveldrive Usb 2.0 Flash Drive   45.00         3
# 14  LF Elite 3D Dazzle Designer Hard Case Cover, L...   21.80         2
# 15                                 Advantus Push Pins   15.26         7
#
#     Discount  Profit
# 0        0.0   41.91
# 1        0.0  219.58
# 13       0.0    4.95
# 14       0.0    6.10
# 15       0.0    6.26
#
# [5 rows x 21 columns]

# %%
# Selecting all rows, and all columns using loc
df.loc[:,:].head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08/11/2021  11/11/2021    Second Class    CG-12520
# 1       2  CA-2016-152156  08/11/2021  11/11/2021    Second Class    CG-12520
# 2       3  CA-2016-138688  12/06/2021  16/06/2021    Second Class    DV-13045
# 3      14  CA-2016-161389  05/12/2021  10/12/2021  Standard Class    IM-15070
# 4      22  CA-2016-137330  09/12/2021  13/12/2021  Standard Class    KB-16585
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
# 3     Irene Maddox   Consumer  United States      Seattle  ...       98103
# 4        Ken Black  Corporate  United States      Fremont  ...       68025
#
#     Region       Product ID         Category Sub-Category  \
# 0    South  FUR-BO-10001798        Furniture    Bookcases
# 1    South  FUR-CH-10000454        Furniture       Chairs
# 2     West  OFF-LA-10000240  Office Supplies       Labels
# 3     West  OFF-BI-10003656  Office Supplies      Binders
# 4  Central  OFF-AR-10000246  Office Supplies          Art
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
# 3        Fellowes PB200 Plastic Comb Binding Machine  407.98         3
# 4                                         Newell 318   19.46         7
#
#    Discount  Profit
# 0       0.0   41.91
# 1       0.0  219.58
# 2       0.0    6.87
# 3       0.2  132.59
# 4       0.0    5.06
#
# [5 rows x 21 columns]

# %%
# Selecting all rows, and selected columns using loc
df.loc[:,('Segment','Country')].head()
# Out:
#      Segment        Country
# 0   Consumer  United States
# 1   Consumer  United States
# 2  Corporate  United States
# 3   Consumer  United States
# 4  Corporate  United States

# %%
# Selected rows and columns between a range of indexes and coulmns=>segment and country
df.loc[1:4,'Segment':'City'].head()
# Out:
#      Segment        Country         City
# 1   Consumer  United States    Henderson
# 2  Corporate  United States  Los Angeles
# 3   Consumer  United States      Seattle
# 4  Corporate  United States      Fremont

# %%
# Selecting all rows, and selected columns using iloc
# This is used to locate rows and columns using index
# Note that it is not inclusive of right hand boundary
df.iloc[1:4,[2,4]].head()
# Out:
#    Order Date       Ship Mode
# 1  08/11/2021    Second Class
# 2  12/06/2021    Second Class
# 3  05/12/2021  Standard Class

# %%
# Selected row and column indexes
df.iloc[[1,4],[2,4,5,8]].head()
# Out:
#    Order Date       Ship Mode Customer ID        Country
# 1  08/11/2021    Second Class    CG-12520  United States
# 4  09/12/2021  Standard Class    KB-16585  United States

# %%
# Range of row and column indexes
df.iloc[1:4,2:5].head()
# Out:
#    Order Date   Ship Date       Ship Mode
# 1  08/11/2021  11/11/2021    Second Class
# 2  12/06/2021  16/06/2021    Second Class
# 3  05/12/2021  10/12/2021  Standard Class

# %%
# Row indexing and filtering not allowed
df.loc[2:7,df['Segment']=="Corporate"]
# Output throughs an error

# %%
# Row level filtering on more than one column with column selection
df.loc[(df['Segment']=="Corporate") & (df['Postal Code']<50000),'Segment':'City'].head()
# Out:
#       Segment        Country           City
# 15  Corporate  United States  New York City
# 16  Corporate  United States  New York City
# 26  Corporate  United States        Decatur
# 27  Corporate  United States        Decatur
# 53  Corporate  United States   Philadelphia

# %%
# Row level filtering on more than one column with column selection
df.iloc[(df['Segment']=="Corporate") & (df['Postal Code']<50000),5:8].head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[113], line 2
#       1 # Row level filtering on more than one column with column selection
# ----> 2 df.iloc[(df['Segment']=="Corporate") & (df['Postal Code']<50000),5:8].head()
#
# File c:\Users\keset\anaconda3\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File c:\Users\keset\anaconda3\lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File c:\Users\keset\anaconda3\lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File c:\Users\keset\anaconda3\lib\site-packages\pandas\core\indexing.py:1452, in _iLocIndexer._validate_key(self, key, axis)
#    1450 if hasattr(key, "index") and isinstance(key.index, Index):
#    1451     if key.index.inferred_type == "integer":
# -> 1452         raise NotImplementedError(
#    1453             "iLocation based boolean "
#    1454             "indexing on an integer type "
#    1455             "is not available"
#    1456         )
#    1457     raise ValueError(
#    1458         "iLocation based boolean indexing cannot use "
#    1459         "an indexable as a mask"
#    1460     )
#    1461 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available
