# %% [markdown]
# # Sorting, Reindexing, Renaming

# %%
import pandas as pd

# %%
df=pd.read_csv('../Data/Demo_sales_data.csv')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08/11/2021  11/11/2021    Second Class    CG-12520
# 1       2  CA-2016-152156  08/11/2021  11/11/2021    Second Class    CG-12520
# 2       3  CA-2016-138688  12/06/2021  16/06/2021    Second Class    DV-13045
# 3      14  CA-2016-161389  05/12/2021  10/12/2021  Standard Class    IM-15070
# 4      22  CA-2016-137330  09/12/2021  13/12/2021  Standard Class    KB-16585
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
# 3     Irene Maddox   Consumer  United States      Seattle  ...       98103
# 4        Ken Black  Corporate  United States      Fremont  ...       68025
#
# ...

# %%
df.sort_values('Segment')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08/11/2021  11/11/2021    Second Class
# 1461    5681  CA-2016-141551  24/09/2021  30/09/2021  Standard Class
# 1458    5675  CA-2016-146318  22/01/2021  27/01/2021  Standard Class
# 1457    5670  CA-2016-142405  11/06/2021  15/06/2021  Standard Class
# 1456    5669  CA-2016-142405  11/06/2021  15/06/2021  Standard Class
# ...      ...             ...         ...         ...             ...
# 1814    7067  CA-2016-147473  30/05/2021  03/06/2021  Standard Class
# 1817    7071  CA-2016-164490  05/09/2021  10/09/2021    Second Class
# 380     1259  US-2016-168620  24/12/2021  28/12/2021    Second Class
# 376     1242  CA-2016-128727  29/08/2021  04/09/2021  Standard Class
# 1293    4988  CA-2016-149279  24/04/2021  28/04/2021  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 0       CG-12520         Claire Gute     Consumer  United States
# ...

# %%
df.sort_values('Postal Code', ascending=False)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1232    4751  CA-2016-127649  07/10/2021  09/10/2021     First Class
# 210      650  CA-2016-160745  11/12/2021  16/12/2021    Second Class
# 211      651  CA-2016-160745  11/12/2021  16/12/2021    Second Class
# 209      649  CA-2016-160745  11/12/2021  16/12/2021    Second Class
# 291     1001  CA-2016-155488  13/11/2021  17/11/2021  Standard Class
# ...      ...             ...         ...         ...             ...
# 2149    8332  CA-2016-153269  09/03/2021  12/03/2021     First Class
# 2150    8333  CA-2016-153269  09/03/2021  12/03/2021     First Class
# 2151    8334  CA-2016-153269  09/03/2021  12/03/2021     First Class
# 2349    9028  US-2016-152415  17/09/2021  22/09/2021  Standard Class
# 2350    9029  US-2016-152415  17/09/2021  22/09/2021  Standard Class
#
#      Customer ID      Customer Name      Segment        Country         City  \
# ...

# %%
# Rename the columns of a DataFrame
df.rename(columns = {'Row ID':'ID'}).head(1)
# Out:
#    ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   1  CA-2016-152156  08/11/2021  11/11/2021  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount  Profit
# 0  261.96         2       0.0   41.91
#
# [1 rows x 21 columns]

# %%
# Sort the index of a DataFrame
df.sort_index(ascending=False).head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2586    9987  CA-2016-125794  29/09/2021  03/10/2021  Standard Class
# 2585    9984  US-2016-157728  22/09/2021  28/09/2021  Standard Class
# 2584    9983  US-2016-157728  22/09/2021  28/09/2021  Standard Class
# 2583    9980  US-2016-103674  06/12/2021  10/12/2021  Standard Class
# 2582    9979  US-2016-103674  06/12/2021  10/12/2021  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2586    ML-17410  Maris LaWare     Consumer  United States   Los Angeles  ...
# 2585    RC-19960    Ryan Crowe     Consumer  United States  Grand Rapids  ...
# 2584    RC-19960    Ryan Crowe     Consumer  United States  Grand Rapids  ...
# 2583    AP-10720    Anne Pryor  Home Office  United States   Los Angeles  ...
# 2582    AP-10720    Anne Pryor  Home Office  United States   Los Angeles  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
# Reset index of DataFrame to row numbers, moving index to columns.
df.reset_index()

# %%
# Drop columns from DataFrame
df.drop(columns=['Row ID', 'Order ID']).head(1)
# Out:
#    Order Date   Ship Date     Ship Mode Customer ID Customer Name   Segment  \
# 0  08/11/2021  11/11/2021  Second Class    CG-12520   Claire Gute  Consumer
#
#          Country       City     State  Postal Code Region       Product ID  \
# 0  United States  Henderson  Kentucky        42420  South  FUR-BO-10001798
#
#     Category Sub-Category                       Product Name   Sales  \
# 0  Furniture    Bookcases  Bush Somerset Collection Bookcase  261.96
#
#    Quantity  Discount  Profit
# 0         2       0.0   41.91
