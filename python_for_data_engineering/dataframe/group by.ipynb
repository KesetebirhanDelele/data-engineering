# %%
import pandas as pd
df=pd.read_csv('../data/employees.csv')

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.groupby(['Gender']).agg({
    'Salary': ['mean','median','std'],
    'Bonus %': ['mean','median','std'],
})
# Out:
#               Salary                           Bonus %
#                 mean   median           std       mean   median       std
# Gender
# Female  90023.923434  89780.0  33622.312591   9.991014   9.5570  5.509655
# Male    91180.669811  90112.0  32463.925257  10.359835  10.1675  5.652222

# %%
df.groupby(['Gender','Team']).agg({
    'Salary': ['min','max','mean','median'],
    'Bonus %': ['min','max','mean','median'],
})
# Out:
#                             Salary                                 Bonus %  \
#                                min     max          mean    median     min
# Gender Team
# Female Business Development  36844  147183  92669.060000  103789.5   1.027
#        Client Services       36927  147183  86430.083333   85934.0   1.763
#        Distribution          35575  149105  81328.162162   80803.0   2.311
#        Engineering           36946  147362  90311.045455   90932.0   1.481
#        Finance               35381  149908  92203.454545   85592.5   1.552
#        Human Resources       35477  149903  93581.837838   98385.0   1.400
#        Legal                 42090  147113  90790.382353   84792.0   1.079
#        Marketing             36643  145988  95074.250000   94514.0   1.451
#        Product               36067  149684  86182.644444   86883.0   1.256
#        Sales                 35884  149654  89814.564103   90582.0   1.825
# ...
