# %% [markdown]
# Reference: [Link Text](https://docs.docker.com/get-started/08_using_compose/)
#
# # Use Docker Compose
#
# Docker Compose is a tool that was developed to help define and share multi-container applications. With Compose, we can create a YAML file to define the services and with a single command, can spin everything up or tear it all down.
#
# The big advantage of using Compose is you can define your application stack in a file, keep it at the root of your project repo (it’s now version controlled), and easily enable someone else to contribute to your project. Someone would only need to clone your repo and start the compose app. In fact, you might see quite a few projects on GitHub/GitLab doing exactly this now.
#
# So, how do we get started?
#
# ## Install Docker Compose
# If you installed Docker Desktop for Windows, Mac, or Linux you already have Docker Compose! Play-with-Docker instances already have Docker Compose installed as well.
#
# Standalone installations of Docker Engine requires Docker Compose to be installed as a separate package, see Install the Compose plugin.
#
# After installation, you should be able to run the following and see version information.
#
#
# ## Docker compose version
# Create the Compose file
# At the root of the /getting-started/app folder or where ever you want create and keep a file named docker-compose.yml.
#
# See the sample in the Docker-compose.yml file in the Docker folder in this vscode.
#
# ## Running Compose file

# %% [markdown]
# Windows PowerShell
# Copyright (C) Microsoft Corporation. All rights reserved.
#
# Install the latest PowerShell for new features and improvements! https://aka.ms/PSWindows
# ### List all contains that are running
# PS C:\Users\keset> docker ps
# CONTAINER ID   IMAGE                           COMMAND        CREATED          STATUS          PORTS                                                                    NAMES
# 57641794e7c1   portainer/portainer-ce:2.11.1   "/portainer"   27 minutes ago   Up 22 minutes   0.0.0.0:8000->8000/tcp, 0.0.0.0:9000->9000/tcp, 0.0.0.0:9443->9443/tcp   portainer
# ### Stop all containers
# PS C:\Users\keset> docker stop portainer
# portainer
# ### Check if all containers have been stopped
# PS C:\Users\keset> docker ps
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES
# ### Remove all containers to for remonstration purposes to see if Compose up will really fire up all containers
# PS C:\Users\keset> docker rm portainer
# portainer
# ### Change directory to where the Docker-compose.yml file is located
# PS C:\Users\keset> cd OneDrive\Desktop\projects\data-engineering\Docker\
# ### Run compose up and see docker starting up. Then refresh the localhost:9443 and enter password
# PS C:\Users\keset\OneDrive\Desktop\projects\data-engineering\Docker> docker compose up
#
#
# [+] Running 1/1
#  ✔ Container portainer  Created                                                                                    0.1s
# Attaching to portainer
# portainer  | INFO 2023/06/30 14:21:05 Encryption key file `portainer` not present
# portainer  | INFO 2023/06/30 14:21:05 Proceeding without encryption key
# portainer  | INFO 2023/06/30 14:21:05 Loading PortainerDB: portainer.db
# portainer  | INFO 2023/06/30 14:21:05 Opened existing store
# portainer  | 2023/06/30 14:21:05 server: Reverse tunnelling enabled
# portainer  | 2023/06/30 14:21:05 server: Fingerprint be:e1:94:45:81:32:71:2a:4b:26:ac:d9:e9:c1:c9:c6
# portainer  | 2023/06/30 14:21:05 server: Listening on 0.0.0.0:8000...
# portainer  | INFO 2023/06/30 14:21:05 [INFO] [cmd,main] Starting Portainer version 2.11.1
# portainer  |
# portainer  |
# portainer  | level=info msg="2023/06/30 14:21:05 [DEBUG] [chisel, monitoring] [check_interval_seconds: 10.000000] [message: starting tunnel management process]"
# portainer  | level=info msg="2023/06/30 14:21:05 [DEBUG] [internal,init] [message: start initialization monitor ]"
# portainer  | level=info msg="2023/06/30 14:21:05 [INFO] [http,server] [message: starting HTTPS server on port :9443]"
# portainer  | level=info msg="2023/06/30 14:21:05 [INFO] [http,server] [message: starting HTTP server on port :9000]"
