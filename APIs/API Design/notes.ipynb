# %% [markdown]
# # Http Request methods
#
# [Link to detailed HTTP resources](https://www.geeksforgeeks.org/http-request-methods-python-requests/)
#
# |Method|	Description|
# |------|---------------|
# |GET|	GET method is used to retrieve information from the given server using a given URI.
# |POST|	POST request method requests that a web server accepts the data enclosed in the body of the request message, most likely for storing it|
# |PUT|	The PUT method requests that the enclosed entity be stored under the supplied URI. If the URI refers to an already existing resource, it is modified and if the URI does not point to an existing resource, then the server can create the resource with that URI.|
# |DELETE|	The DELETE method deletes the specified resource
# |HEAD|	The HEAD method asks for a response identical to that of a GET request, but without the response body.|
# |PATCH|	It is used for modify capabilities. The PATCH request only needs to contain the changes to the resource, not the complete resource|

# %% [markdown]
# # FastAPI
#
# [Online resources](https://fastapi.tiangolo.com/tutorial/)

# %% [markdown]
# # Pydantic Documentation
#
# [Link](https://docs.pydantic.dev/latest/)

# %% [markdown]
# # Hands on Video from amigoscode
# https://www.youtube.com/watch?v=GN6ICac3OXY

# %% [markdown]
# # Thunder Client Get equest
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Thunder Post Client Request
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # New Get Request to check if new client Rita was added in Json File
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Also check it in the Web by refreshing the link http://127.0.0.1:8000/api/v1/users
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Interactive API Documentation using Swagger on this link:
# http://127.0.0.1:8000/docs
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Documentation showing Schema of Users Table and allowed values of Gender
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Expand and interact with Get and Post commands to read database and add new user

# %% [markdown]
# >Go to video to see how interactive API interface is used to look at curl commands (that can be copy pasted on terminal and get list of users), url to run on web and list of users:
#
# "C:\Users\keset\Videos\Captures\FastAPI - Swagger UI - Google Chrome 2023-07-26 20-36-53.mp4"

# %% [markdown]
# # Non-interactive API interface
# http://127.0.0.1:8000/redoc
#
# >Note that you can download API specification
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Deleting a record using interactive API
#
# > Read available records using Get to check remaining records
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Deleting record using Thunder Client
#
# http://localhost:8000/api/v1/users/3fcdabf8-0e37-4b87-85ce-1517d17e9962 (later part is user_id)
#
# > Note that re-sending this code will give a success message and it needs to be fixed. See next post to address this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Re-deleting a deleted item after adding HTTPException in main.py
#
# >Note 404 error
#
# ![image.png](attachment:image.png)
