# %% [markdown]
# # Data Warehouses
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Comparison of Star and Snow Flake Schemas
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Galaxy Schema
#
# ![image.png](attachment:image.png)
