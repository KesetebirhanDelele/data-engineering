# %% [markdown]
# # Push Ingestion Pipeline
#
# ![image.png](attachment:image.png)

# %% [markdown]
# __Note:__
# > that you can use API to push data directly from a data source to a database skipping a buffer
# > MQTT buffer can be used by a client to send data directly to a storage without using API
