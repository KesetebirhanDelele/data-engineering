# %% [markdown]
# # Batch Pipleine
# Definition: A job that gets scheduled and access data from a store
#
#
# __Advantage over streaming pipeline__: you can do analysis on a big chunk of data to look at the big picture

# %% [markdown]
# ![image.png](attachment:image.png)
