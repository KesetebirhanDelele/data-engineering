# %% [markdown]
# # Lambda Architecture
#
# Two options can be supported using Lambda architecure where by:
#
# 1. a streaming data can be sent into storage or
#
# 2. batch processing can tap into streamed data and sends it into storage.
#
# ![image.png](attachment:image.png)
