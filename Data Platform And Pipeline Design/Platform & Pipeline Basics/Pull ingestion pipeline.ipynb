# %% [markdown]
# # Pull Ingestion Pipeline
#
# > The source of data (eg SQL, SAP database) is not an active date source that pushes data

# %% [markdown]
# > Connector could make a __shceduled pull__ like a piece of Python Code or Apache or make __active pulls__ using Azure Data Factory or Altrix

# %% [markdown]
# ![image.png](attachment:image.png)
