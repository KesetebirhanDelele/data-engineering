# %% [markdown]
# # Streaming pipeline
#
# > Constant flow of data through a buffer and data is processed immediately. Eg Spark

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
