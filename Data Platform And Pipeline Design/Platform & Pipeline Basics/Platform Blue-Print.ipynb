# %% [markdown]
# # General End-to-End Pipeline
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 1: Convert Date into JSON data type using Pandas
#
#
# Step 2: Send it using API to a storage system
#
#
# Step 3: First storage is a buffer which is a holding place before the data is processed
#
#
# Step 4: Processing Framework to analyze and clean data
#
#
# Step 5: Permanent storage
#
#
# Step 6: Visualization

# %% [markdown]
# # Platform Blue-Print
# ![image.png](attachment:image.png)
#
# # Platform Blue-Print Example
# ![image-2.png](attachment:image-2.png)
