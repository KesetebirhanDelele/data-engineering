# %% [markdown]
# Note:
#
# 1. Python used to query NoSQL databases
# 2. Schema on demand: Data stored in columns and hence no set limit on that.

# %% [markdown]
# ![image.png](attachment:image.png)
