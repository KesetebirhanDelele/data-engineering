# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ETL vs ELT
#
# Note:
#
# ETL needs a separate computational power for transformation that accepts data on the fly, transform it and then send to warehouse. This process is expensive and makes process slow.
#
# On the other hand, during ELT, data is already loaded using copy command to a warehouse and transofrmation takes place in the backend with an existing computational power. This makes loading very fast, and transformation inexpensive.

# %% [markdown]
# ![image.png](attachment:image.png)
